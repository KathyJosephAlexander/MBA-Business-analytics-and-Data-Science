# %% [markdown]
# <a href="https://colab.research.google.com/github/KathyJosephAlexander/MBA-Business-analytics-and-Data-Science/blob/main/supermarket_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("Supermarket_sales.csv")

# %%
df
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total        Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715  01-05-2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200  03-08-2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255  03-03-2019
# 3       Health and beauty      58.22         8  23.2880  489.0480   1/27/2019
# 4       Sports and travel      86.31         7  30.2085  634.3785  02-08-2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
df.tail()
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax      Total        Date  \
# 995    Health and beauty      40.35         1   2.0175    42.3675   1/29/2019
# 996   Home and lifestyle      97.38        10  48.6900  1022.4900  03-02-2019
# 997   Food and beverages      31.84         1   1.5920    33.4320  02-09-2019
# 998   Home and lifestyle      65.82         1   3.2910    69.1110   2/22/2019
# 999  Fashion accessories      88.34         7  30.9190   649.2990   2/18/2019
#
#       Time  Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
df.InvoiceID
# Out:
# 0      750-67-8428
# 1      226-31-3081
# 2      631-41-3108
# 3      123-19-1176
# 4      373-73-7910
#           ...
# 995    233-67-5758
# 996    303-96-2227
# 997    727-02-1313
# 998    347-56-2442
# 999    849-09-3807
# Name: InvoiceID, Length: 1000, dtype: object

# %%
df.InvoiceID[1]
# Out:
# '226-31-3081'

# %%
df.Branch[100]
# Out:
# 'C'

# %%
print(df.Customertype)
# Out:
# 0      Member
# 1      Normal
# 2      Normal
# 3      Member
# 4      Normal
#         ...
# 995    Normal
# 996    Normal
# 997    Member
# 998    Normal
# 999    Member
# Name: Customertype, Length: 1000, dtype: object

# %%
df.shape
# Out:
# (1000, 18)

# %%
if df.City[18] == "Yangon":
  print(df.Branch[18])
# Out:
# A

# %%
df.Unitprice.max()
# Out:
# 99.96

# %%
df.Unitprice.min()
# Out:
# 10.08

# %%
df.Quantity.loc[df['Productline'] == "Health and beauty"].max()
# Out:
# 10

# %%
df.Quantity.loc[df['Productline'] == "Health and beauty"].max()
# Out:
# 10

# %%
df.Quantity.loc[df['Productline'] == "Health and beauty"].min()
# Out:
# 1

# %%
df.loc[df['Productline'] == "Health and Beauty"].max()
# Out:
# No                         NaN
# InvoiceID                  NaN
# Branch                     NaN
# City                       NaN
# Customertype               NaN
# Gender                     NaN
# Productline                NaN
# Unitprice                  NaN
# Quantity                   NaN
# Tax                        NaN
# Total                      NaN
# Date                       NaN
# Time                       NaN
# Payment                    NaN
# cogs                       NaN
# gross_margin_percentage    NaN
# gross_iincome              NaN
# Rating                     NaN
# dtype: object

# %%
df.Quantity.loc[df['Productline'] == "Health and Beauty"].mean()
# Out:
# nan

# %%
a=df.loc[(df["City"]=="Yangon")]
a["Tax"].max()
# Out:
# 49.49

# %%
a=df.loc[(df["City"]=="Yangon")]
b=df.loc[(df["City"]=="Mandalay")]
print(a["Total"].sum())
print(b["Total"].sum())
# Out:
# 106200.3705
# 106197.67199999999

# %%
a=df.loc[(df["City"]=="Yangon")]
z=a.groupby("Productline").min()
print(z["Quantity"].min())
# Out:
# 1

# %%
import matplotlib.pyplot as plt
x=df["Tax"]
y=df["Unitprice"]
plt.plot(x,y)

# %%
a=df["gross_margin_percentage"].max()
df.loc[df["gross_margin_percentage"]==a]
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
a=df.loc[df["Gender"]=="Male"]
b=df.loc[df["Gender"]=="Female"]
z=a["gross_iincome"].max()
y=b["gross_iincome"].max()
if y>z:
    print("Female has a higher profit margin")
else:
    print("Male has a higher profit margin")
df.groupby("Customertype").max()
# Out:
# Female has a higher profit margin
#                 No    InvoiceID Branch    City Gender        Productline  \
# Customertype
# Member        1000  895-66-0685      C  Yangon   Male  Sports and travel
# Normal         999  898-04-2717      C  Yangon   Male  Sports and travel
#
#               Unitprice  Quantity    Tax    Total       Date   Time  Payment  \
# Customertype
# Member            99.96        10  49.65  1042.65  3/30/2019  20.59  Ewallet
# Normal            99.96        10  49.49  1039.29  3/30/2019  20.59  Ewallet
#
#                cogs  gross_margin_percentage  gross_iincome  Rating
# Customertype
# Member        993.0                 4.761905          49.65    10.0
# Normal        989.8                 4.761905          49.49    10.0

# %%
a=df.groupby("InvoiceID").min()
print(a["gross_iincome"].min())
# Out:
# 0.5085

# %%
df["Rating"].max()
a=df.loc[df["Gender"]=="Male"].max()
b=df.loc[df["Gender"]=="Female"].max()
if a["Rating"]>b["Rating"]:
    print("Males give higher rating")
    print(a)
else:
    print("Females  the higher rating")
    print(b)
# Out:
# Females  the higher rating
# No                                      1000
# InvoiceID                        895-03-6665
# Branch                                     C
# City                                  Yangon
# Customertype                          Normal
# Gender                                Female
# Productline                Sports and travel
# Unitprice                              99.73
# Quantity                                  10
# Tax                                    49.65
# Total                                1042.65
# Date                               3/30/2019
# Time                                   20.59
# Payment                              Ewallet
# cogs                                   993.0
# gross_margin_percentage             4.761905
# gross_iincome                          49.65
# Rating                                  10.0
# dtype: object

# %%
a=df.groupby("City")
y=a["gross_iincome"].sum()
print(y)
# Out:
# City
# Mandalay     5057.0320
# Naypyitaw    5265.1765
# Yangon       5057.1605
# Name: gross_iincome, dtype: float64

# %%
import matplotlib.pyplot as plt
x=df["Rating"]
y=df["Unitprice"]
plt.scatter(x,y)
